# %%
from down_sampling.main import Downsampler
import pandas as pd

# %%
data_name = "billionaires"
data = pd.read_csv(f"../data/{data_name}.csv")

# %%
generator = Downsampler()
generator.load_data(data)

# %%
# Create synthetic data
dataset = generator.downsample(feature="gender", majority="M", minority="F", ratio=.1, upweight=True)
# Out:
# /Users/john/Documents/brown/cs1970/models/down_sampling/main.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   majority_data['weights'] = majority_weight
# /Users/john/Documents/brown/cs1970/models/down_sampling/main.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minority_data['weights'] = minority_weight

# %%
dataset
# Out:
#      rank  finalWorth               category            personName   age  \
# 0     100       16700  Finance & Investments  Vicky Safra & family  70.0
# 1    2133        1300             Technology        Michael Krasny  69.0
# 2     567        4800          Manufacturing  Winifred J. Marquart  63.0
# 3     383        6600          Manufacturing         Rahel Blocher  47.0
# 4     905        3200             Technology            David Filo  56.0
# ..    ...         ...                    ...                   ...   ...
# 706  2540        1000             Healthcare        Loo Choon Yong  74.0
# 707   184        9800              Logistics    Tanya Saadé Zeenny  55.0
# 708   534        5000            Real Estate      Zhu Yan & family   NaN
# 709   215        9000        Food & Beverage     Anthony von Mandl  73.0
# 710  1217        2500       Fashion & Retail          Susan Alfond  77.0
#
#            country                city               source  \
# ...
