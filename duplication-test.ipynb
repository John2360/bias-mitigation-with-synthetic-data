# %%
from duplication.main import DuplicationGenerator
import pandas as pd

# %%
data_name = "billionaires"
data = pd.read_csv(f"../data/{data_name}.csv")

# %%
generator = DuplicationGenerator()
generator.load_data(data)

# %%
# Create synthetic data
synthetic_data = generator.generate(feature="gender", majority="M", minority="F", n_samples=100)

# %%
synthetic_data
# Out:
#       rank  finalWorth               category               personName   age  \
# 1488  1434        2100             Technology         Leonid Radvinsky  40.0
# 1475  1434        2100        Food & Beverage          Daniel Lubetzky  54.0
# 217    215        9000        Food & Beverage        Anthony von Mandl  73.0
# 533    534        5000  Finance & Investments                Ron Baron  79.0
# 469    466        5500             Technology         Patrick Collison  34.0
# ...    ...         ...                    ...                      ...   ...
# 96      97       17400            Real Estate              Donald Bren  90.0
# 2314  2259        1200  Media & Entertainment            Guy Laliberté  63.0
# 2524  2405        1100             Healthcare               Xiu Laigui  68.0
# 142    142       12200             Healthcare  Jiang Rensheng & family  69.0
# 1289  1272        2400  Media & Entertainment          Kalanithi Maran  57.0
#
# ...
