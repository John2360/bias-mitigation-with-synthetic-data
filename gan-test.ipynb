# %%
# !pip3 install ctgan
# Out:
# Collecting ctgan
#   Downloading ctgan-0.8.0-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.11/site-packages (from ctgan) (4.66.1)
# Requirement already satisfied: rdt<2.0,>=1.6.1 in /usr/local/lib/python3.11/site-packages (from ctgan) (1.8.0)
# Requirement already satisfied: numpy<2,>=1.23.3 in /usr/local/lib/python3.11/site-packages (from ctgan) (1.26.1)
# Requirement already satisfied: scikit-learn<2,>=1.1.3 in /usr/local/lib/python3.11/site-packages (from ctgan) (1.3.1)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.11/site-packages (from ctgan) (2.1.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/site-packages (from ctgan) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas>=1.5.0->ctgan) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas>=1.5.0->ctgan) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/site-packages (from pandas>=1.5.0->ctgan) (2023.3)
# Requirement already satisfied: Faker<20,>=17 in /usr/local/lib/python3.11/site-packages (from rdt<2.0,>=1.6.1->ctgan) (19.13.0)
# Requirement already satisfied: scipy<2,>=1.9.2 in /usr/local/lib/python3.11/site-packages (from rdt<2.0,>=1.6.1->ctgan) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/site-packages (from scikit-learn<2,>=1.1.3->ctgan) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/site-packages (from scikit-learn<2,>=1.1.3->ctgan) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from torch>=2.0.0->ctgan) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/site-packages (from torch>=2.0.0->ctgan) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/site-packages (from torch>=2.0.0->ctgan) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch>=2.0.0->ctgan) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch>=2.0.0->ctgan) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/site-packages (from torch>=2.0.0->ctgan) (2023.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->ctgan) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->ctgan) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/site-packages (from sympy->torch>=2.0.0->ctgan) (1.3.0)
# Downloading ctgan-0.8.0-py2.py3-none-any.whl (27 kB)
# Installing collected packages: ctgan
# Successfully installed ctgan-0.8.0

# %%
from ctgan import CTGAN
from ctgan import load_demo
import pandas as pd

# %%
data_name = "billionaires"
data = pd.read_csv(f"../data/{data_name}.csv")

# Names of the columns that are discrete
discrete_columns = data.columns.tolist()

# %%
ctgan = CTGAN(epochs=10)
ctgan.fit(data, discrete_columns)

# %%
# Create synthetic data
synthetic_data = ctgan.sample(1000)

# %%
synthetic_data
# Out:
#      rank  finalWorth               category               personName   age  \
# 0    1368       93000                 Energy          Urs Wietlisbach  49.0
# 1     982       58800             Technology          Sergei Galitsky  75.0
# 2    2405       38900            Diversified              Patrick Lee  42.0
# 3     230        1600             Healthcare         Charles Bronfman  64.0
# 4      97       42900              Logistics           Michal Solowow  71.0
# ..    ...         ...                    ...                      ...   ...
# 995  1905        1500        Food & Beverage    Alessandra Garavoglia  67.0
# 996    72       68000            Diversified          Daniel Sundheim  62.0
# 997  2405        9600       Fashion & Retail  Savitri Jindal & family  51.0
# 998    21       22000  Finance & Investments                Li Xiting  62.0
# 999   332        5900  Media & Entertainment                   Sky Xu  49.0
#
#            country          city                             source  \
# 0          Hungary      Oakville                     Private equity
# 1        Australia    Phnom Penh                Alcoholic beverages
# 2           Cyprus       Liberty                         Healthcare
# 3         Thailand  Jacksonville                       Satellite TV
# 4            China      Shenzhen                              Paper
# ..             ...           ...                                ...
# 995  United States        Ningbo                             Cement
# 996            NaN     Landsberg                            Trading
# 997          Italy      Quanzhou  Book distribution, transportation
# 998  United States       Midland                          Oil & gas
# 999        Armenia         Bacau                               IKEA
#
#                 industries countryOfCitizenship  ... cpi_change_country  \
# 0            Manufacturing                India  ...                4.5
# 1                  Service               Canada  ...                0.6
# 2          Food & Beverage               Brazil  ...                1.7
# 3            Manufacturing              Algeria  ...                7.7
# 4              Diversified                Qatar  ...                7.5
# ..                     ...                  ...  ...                ...
# 995  Finance & Investments        United States  ...                7.9
# 996                 Sports                Japan  ...                0.4
# 997       Fashion & Retail               Mexico  ...                0.7
# 998             Technology        United States  ...                0.5
# 999       Fashion & Retail               France  ...                1.1
#
#               gdp_country gross_tertiary_education_enrollment  \
# 0     $1,736,425,629,520                                 88.5
# 1    $21,427,700,000,000                                 63.9
# 2       $303,175,127,598                                 75.9
# 3       $226,848,050,820                                 50.6
# 4    $21,427,700,000,000                                 70.2
# ..                    ...                                 ...
# 995     $421,142,267,938                                 63.4
# 996      $38,574,069,149                                 36.3
# 997     $364,701,517,788                                 12.4
# 998   $1,119,190,780,753                                 50.6
# 999                   NaN                                51.4
#
#     gross_primary_education_enrollment_country life_expectancy_country  \
# 0                                         98.7                    78.5
# 1                                        101.8                    80.8
# 2                                         94.2                    83.3
# 3                                        104.0                    69.6
# 4                                        100.2                    78.5
# ..                                         ...                     ...
# 995                                      100.2                    81.3
# 996                                      100.9                    83.3
# 997                                      103.9                    71.1
# 998                                      104.0                    78.5
# 999                                      102.6                    69.4
#
#     tax_revenue_country_country total_tax_rate_country population_country  \
# 0                          17.4                   30.6        270203917.0
# 1                          14.2                   36.6        328239523.0
# 2                           9.6                   20.4          5818553.0
# 3                          15.6                   59.1         67059887.0
# 4                           9.6                   59.2         67059887.0
# ..                          ...                    ...                ...
# 995                        23.9                   59.2        328239523.0
# 996                        37.2                   38.1          5520314.0
# 997                         9.6                   36.6          5520314.0
# 998                        13.1                   36.6        328239523.0
# 999                        11.7                   29.2         96462106.0
#
#     latitude_country longitude_country
# 0          37.090240        -95.712891
# 1          49.817492         30.802498
# 2          56.130366         64.585262
# 3          51.919438         19.699024
# 4          55.378051          8.468946
# ..               ...               ...
# 995              NaN         19.145136
# 996              NaN         31.165580
# 997        51.165691          8.227512
# 998        35.861660          9.501785
# 999        38.963745          5.291266
#
# [1000 rows x 35 columns]
